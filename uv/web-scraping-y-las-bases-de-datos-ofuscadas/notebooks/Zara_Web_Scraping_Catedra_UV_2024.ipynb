# %% [markdown]
# # Zara Web Scraping

# %% [markdown]
# ## Descripción

# %% [markdown]
# Ejemplo de descarga con Sitemap

# %% [markdown]
# ## Imports

# %%
import requests
import datetime
import bs4
import pandas
import random
random.seed = 42
import time

# %% [markdown]
# ## Configuración

# %%
CONFIGURATION = {
    "SITEMAP_URL": "https://www.zara.com/sitemaps/sitemap-images-es-es.xml.gz",
    "USER_AGENT": "Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0",
    "PRODUCT_LIMIT": 50,
    "THROTTLE": 1
}

# %% [markdown]
# ## Sitemap

# %%
header="Mozilla/5.0 (Windows NT 6.3; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0"
# !wget "$header" "https://www.zara.com/sitemaps/sitemap-images-es-es.xml.gz" -O index
# Out:
# --2024-03-27 02:15:26--  http://mozilla/5.0%20(Windows%20NT%206.3;%20Win64;%20x64;%20rv:109.0)%20Gecko/20100101%20Firefox/115.0
# Resolving mozilla (mozilla)... failed: Name or service not known.
# wget: unable to resolve host address ‘mozilla’
# --2024-03-27 02:15:26--  https://www.zara.com/sitemaps/sitemap-images-es-es.xml.gz
# Resolving www.zara.com (www.zara.com)... 23.48.203.82, 23.48.203.75, 2600:1408:ec00:20::1735:23a7, ...
# Connecting to www.zara.com (www.zara.com)|23.48.203.82|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-03-27 02:15:26 ERROR 403: Forbidden.

# %%
sitemap_response = requests.get(CONFIGURATION["SITEMAP_URL"], headers={"User-Agent": CONFIGURATION["USER_AGENT"]})

# %%
with open("sitemap-images-es-es.xml.gz", "wb+") as file:
  file.write(sitemap_response.content)

# %%
# !gunzip "sitemap-images-es-es.xml.gz" -y
# Out:
# gzip: invalid option -- 'y'
# Try `gzip --help' for more information.

# %%
sitemap_content = ""
with open("sitemap-images-es-es.xml") as file:
  sitemap_content = file.read()

# %%
sitemap_parsed = bs4.BeautifulSoup(sitemap_content)
products = sitemap_parsed.select("loc")
"total products", len(products)
# Out:
# <ipython-input-8-5f0f3123739c>:1: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   sitemap_parsed = bs4.BeautifulSoup(sitemap_content)
# ('total products', 4797)

# %%
products_links = [p.text for p in products]

# %% [markdown]
# ## Parseo página de producto

# %%
def clean(element):
  if not element:
    return element

  return element.text.strip()

# %%
def parse_product_page(link: str, driver):
  driver.get(link)

  return {
      "name": driver.find_element(by=By.CLASS_NAME, value="product-detail-info__header-name").text.strip(),
      "price": driver.find_element(by=By.CLASS_NAME, value="money-amount__main").text.strip(),
      "description": driver.find_element(by=By.CLASS_NAME, value="expandable-text__inner-content").get_attribute("innerText").strip(),
      "image_link": driver.find_element(by=By.TAG_NAME, value="body").find_element(by=By.CLASS_NAME, value="media-image img").get_dom_attribute("src"),
  }

# %% [markdown]
# ## Parseo selección de productos

# %% [markdown]
# ### Secreto

# %%
# !pip install -q google-colab-selenium

# %%
import google_colab_selenium
from selenium.webdriver.common.by import By
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument(f"user-agent={CONFIGURATION['USER_AGENT']}")

driver = google_colab_selenium.Chrome(options=options)
# Out:
#             <div class="spinner-container">
#                 <div class="spinner" id="6f54ae50-0307-4811-a79b-37a1c58678d4-circle"></div>
#                 <div class="spinner-text" id="6f54ae50-0307-4811-a79b-37a1c58678d4-text">Updating and upgrading APT</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="e43c3574-f37e-4cac-8055-e2e011365623-circle"></div>
#                 <div class="spinner-text" id="e43c3574-f37e-4cac-8055-e2e011365623-text">Downloading Google Chrome</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="8dd58b47-435b-4829-968f-c2bd1e6fe6f3-circle"></div>
#                 <div class="spinner-text" id="8dd58b47-435b-4829-968f-c2bd1e6fe6f3-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>

# %%
# Create a request interceptor
def interceptor(request):
    del request.headers["User-Agent"]  # Delete the header first
    print(request.headers)
    request.headers["User-Agent"] = CONFIGURATION["USER_AGENT"]
    request.headers["Accept"] = "*/*"
    request.headers["Accept-Language"] = "es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3"
    request.headers["Accept-Encoding"] = "gzip, deflate, br"
    request.headers["Referer"] = "https://www.zara.com/es/es/wonder-rose-90-ml-p20120807.html"
    request.headers["Connection"] = "keep-alive"
    request.headers["Cookie"] = "ITXDEVICEID=02fc621d5471ab1040783cd24874e775; _abck=FF9A53297639EC45342B57AFD91E10F2~0~...~-1~-1~-1; bm_sz=E94F23C1140583A524E01EFC24C199A0~~4535365~3360321; ITXSESSIONID=57bdb2f81a4e29114678207d12eb7064; ak_bmsc=340240611C3998410525FEF6FA35C487~000000000000000000000000000000~...; TS0122c9b6=0163574cbd1927218894f9d1b7a866f032110220a110d3c13cbd6d4552c000d62b4df9137889a37f23324903f2beb5f03883446246; bm_mi=AC1FAC123FB78FE5DFA228CAEEC0EE5E~~1; bm_sv=9FB71229F21F800EAD22E5C1CD0581C8~YAAQI7U+F8DSv3OOAQAAGNA8fRfxsogqjLEDtHmtsXM4JYovp1zx7uHo5wA8PiY7bmPqdauePMqawsRF5SGh31GTpuvoLLUMfwA/pH4mGu4m+9sTNei0GlULrVYy4xyPaNqDT4jFwdOlBi+VIYzGbWIvHuFGSyXw3jLzBXGq3pQ6bNvvSvdVRWUpbYg3CMQWDK7i8JDmXcXdfCE3h8ZHOoF9VQUxgBTqwtgrb9Khjy+fw/GHn3M3CjjA02uHdw==~1; _itxo11y_ses.01fa=*; _itxo11y_id.01fa=8448decf-85cb-44ff-9644-96b815c30a98.1711497544.1.1711498137..034d9275-cac8-4bbd-b09f-b1116edaf886..3eea7c3d-a33e-46d0-91f1-a40316df1695.1711497543958.13; rid=68de075f-8b7f-4c6f-bb12-4fbab79806b1; storepath=es%2Fes; IDROSTA=d8cd15c6c856:145aeb6a889fd0319c43c2691; 826b75e46a856af63aa6a715b40616e7=ae627a78bc1f75d06af2d41d1e0e35a2; cart-was-updated-in-standard=true; OptanonConsent=isGpcEnabled=1&datestamp=Wed+Mar+27+2024+00%3A59%3A39+GMT%2B0100+(hora+est%C3%A1ndar+de+Europa+central)&version=202401.1.0&browserGpcFlag=1&isIABGlobal=false&hosts=&consentId=28b5ee63-138e-4bce-b59b-de8d04d46ad7&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0003%3A0%2CC0004%3A0; lastRskxRun=1711497545505; rskxRunCookie=0; rCookie=3mlp8nvgymus2tzpdofiklu91g5ya; OptanonAlertBoxClosed=2024-03-26T23:59:39.459Z"
    request.headers["Sec-Fetch-Dest"] = "empty"
    request.headers["Sec-Fetch-Mode"] = "cors"
    request.headers["Sec-Fetch-Site"] = "same-origin"
    request.headers["Sec-GPC"] = "1"
    request.headers["TE"] = "trailers"

# Set the interceptor on the driver
driver.request_interceptor = interceptor

# %%
def throttle():
  time.sleep(CONFIGURATION["THROTTLE"])

# %% [markdown]
# ### Parsing

# %%
parsed_products = []

prod_products_links = list(products_links)
# random.shuffle(prod_products_links)
prod_products_links = products_links[:CONFIGURATION["PRODUCT_LIMIT"]]

for link in prod_products_links:
  index = len(parsed_products) + 1
  if index > CONFIGURATION["PRODUCT_LIMIT"]:
    break

  print(link)
  throttle()
  try:
    parsed_products.append(parse_product_page(link, driver))
    print(f"({index}/{CONFIGURATION['PRODUCT_LIMIT']})", "-", index / CONFIGURATION["PRODUCT_LIMIT"] * 100, "%")
  except:
    print("error", link)
# Out:
# https://www.zara.com/es/es/wonder-rose-90-ml-p20120807.html
# 3.0 %
# https://www.zara.com/es/es/mini-shorts-rayas-p06929405.html
# 4.0 %
# https://www.zara.com/es/es/camiseta-rib-algodon-p00085900.html
# 5.0 %
# https://www.zara.com/es/es/sudadera-minnie-mouse---disney-p00061566.html
# 6.0 %
# https://www.zara.com/es/es/falda-pareo-estampada-midi-p09878109.html
# 7.0 %
# https://www.zara.com/es/es/calcetines-rib-pack-3-p03992419.html
# 8.0 %
# https://www.zara.com/es/es/vestido-corto-estampado-floral-cinturon-p02737839.html
# 9.0 %
# https://www.zara.com/es/es/mocasin-piel-cadena-p12587310.html
# 10.0 %
# https://www.zara.com/es/es/bermuda-denim-trf-trabillas-ajustables-p08727001.html
# 11.0 %
# https://www.zara.com/es/es/camisa-elastica-rayas-p07545541.html
# 12.0 %
# https://www.zara.com/es/es/mule-acharolado-tacon-p12234310.html
# 13.0 %
# https://www.zara.com/es/es/sudadera-texto-relieve-p02224666.html
# 14.0 %
# https://www.zara.com/es/es/jersey-punto-ochos-p02756755.html
# 15.0 %
# https://www.zara.com/es/es/pack-tres-calcetines-largos-basicos-p04934690.html
# 16.0 %
# https://www.zara.com/es/es/chaqueta-punto-contraste-p04696401.html
# 17.0 %
# https://www.zara.com/es/es/pantalon-punto-rayas-limited-edition-p03284606.html
# 18.0 %
# https://www.zara.com/es/es/neceser-acolchado-p11416330.html
# 19.0 %
# https://www.zara.com/es/es/bolso-maternidad-borreguillo-p11583230.html
# 20.0 %
# https://www.zara.com/es/es/bailarina-piel-p18855330.html
# 21.0 %
# https://www.zara.com/es/es/jeans-wide-fit-x-studio-nicholson-p02553362.html
# 22.0 %
# https://www.zara.com/es/es/camisa-larga-gabardina-cinturon-p01957006.html
# 23.0 %
# https://www.zara.com/es/es/camiseta-punto-cremallera-p00339609.html
# 24.0 %
# https://www.zara.com/es/es/jersey-punto-oversize-p09598288.html
# 25.0 %
# https://www.zara.com/es/es/pendientes-aro-ajustables-p01856040.html
# 26.0 %
# https://www.zara.com/es/es/deportivo-textura-p12201320.html
# 27.0 %
# https://www.zara.com/es/es/pantalon-popelin-p06917966.html
# 28.0 %
# https://www.zara.com/es/es/camiseta-basica-poliamida-p01165616.html
# 29.0 %
# https://www.zara.com/es/es/botin-deportivo-avengers---marvel-p13214330.html
# 30.0 %
# https://www.zara.com/es/es/vestido-satinado-zw-collection-p02126965.html
# 31.0 %
# https://www.zara.com/es/es/pala-serraje-costuras-p12733320.html
# 32.0 %
# https://www.zara.com/es/es/pantalon-tecnico-bolsillos-p01063501.html
# 33.0 %
# https://www.zara.com/es/es/abrigo-entallado-soft-p08073253.html
# 34.0 %
# https://www.zara.com/es/es/navy-black-800-black-100ml-p20210695.html
# 35.0 %
# https://www.zara.com/es/es/camiseta-texto-contraste-p00264037.html
# 36.0 %
# https://www.zara.com/es/es/parka-water-and-wind-protection-p01255777.html
# 37.0 %
# https://www.zara.com/es/es/top-denim-trf-corsetero-p03643353.html
# 38.0 %
# https://www.zara.com/es/es/pantalon-efecto-piel-p08281651.html
# 39.0 %
# https://www.zara.com/es/es/camiseta-estructura-p04092410.html
# 40.0 %
# https://www.zara.com/es/es/traje-levita-y-pantalon-zw-collection-pT0896684922.html
# 41.0 %
# https://www.zara.com/es/es/camisa-estampada-p02889754.html
# 42.0 %
# https://www.zara.com/es/es/camiseta-rib-tirantes-p00264838.html
# 43.0 %
# https://www.zara.com/es/es/bailarina-basica-p12522330.html
# 44.0 %
# https://www.zara.com/es/es/falda-mini-doble-capa-volumen-p02312731.html
# 45.0 %
# https://www.zara.com/es/es/leggings-ciclistas-cintura-contraste-p01165016.html
# 46.0 %
# https://www.zara.com/es/es/abrigo-lana-manteco-zw-collection-p02109775.html
# 47.0 %
# https://www.zara.com/es/es/conjunto-sujetador-y-braguita-moldeadores-pT0135580260.html
# error https://www.zara.com/es/es/conjunto-sujetador-y-braguita-moldeadores-pT0135580260.html
# https://www.zara.com/es/es/neceser-grabado-p13703320.html
# 48.0 %
# https://www.zara.com/es/es/vestido-satinado-tie-dye-p06962022.html
# 49.0 %
# https://www.zara.com/es/es/vestido-estampado-geometrico-p02829145.html
# 50.0 %
# https://www.zara.com/es/es/botin-tacon-brillos-p12136310.html
# 51.0 %

# %%
df = pandas.DataFrame(parsed_products)
df
# Out:
#                                        name       price  \
# 0                         WONDER ROSE 90 ML   10,95 EUR
# 1                         MINI SHORTS RAYAS   22,95 EUR
# 2                      CAMISETA RIB ALGODÓN   15,95 EUR
# 3            SUDADERA MINNIE MOUSE © DISNEY   15,95 EUR
# 4                FALDA PAREO ESTAMPADA MIDI   29,95 EUR
# 5                     CALCETINES RIB PACK 3    9,95 EUR
# 6   VESTIDO CORTO ESTAMPADO FLORAL CINTURÓN   35,95 EUR
# 7                       MOCASÍN PIEL CADENA   39,95 EUR
# 8    BERMUDA DENIM TRF TRABILLAS AJUSTABLES   25,95 EUR
# 9                     CAMISA ELÁSTICA RAYAS   29,95 EUR
# 10                    MULE ACHAROLADO TACÓN   27,95 EUR
# 11                   SUDADERA TEXTO RELIEVE   19,95 EUR
# 12                       JERSEY PUNTO OCHOS   22,95 EUR
# 13      PACK TRES CALCETINES LARGOS BÁSICOS    3,95 EUR
# 14                 CHAQUETA PUNTO CONTRASTE   45,95 EUR
# 15     PANTALÓN PUNTO RAYAS LIMITED EDITION   25,95 EUR
# 16                        NECESER ACOLCHADO   14,95 EUR
# 17             BOLSO MATERNIDAD BORREGUILLO   55,95 EUR
# 18                           BAILARINA PIEL   29,95 EUR
# 19        JEANS WIDE FIT X STUDIO NICHOLSON   59,95 EUR
# 20          CAMISA LARGA GABARDINA CINTURÓN   29,95 EUR
# 21                CAMISETA PUNTO CREMALLERA   12,95 EUR
# 22                    JERSEY PUNTO OVERSIZE   29,95 EUR
# 23                PENDIENTES ARO AJUSTABLES   12,95 EUR
# 24                        DEPORTIVO TEXTURA   29,95 EUR
# 25                         PANTALÓN POPELÍN   25,95 EUR
# 26                CAMISETA BÁSICA POLIAMIDA    6,95 EUR
# 27        BOTÍN DEPORTIVO AVENGERS © MARVEL   32,95 EUR
# 28           VESTIDO SATINADO ZW COLLECTION   29,95 EUR
# 29                    PALA SERRAJE COSTURAS   39,95 EUR
# 30               PANTALÓN TÉCNICO BOLSILLOS   15,95 EUR
# 31                    ABRIGO ENTALLADO SOFT   49,95 EUR
# 32             NAVY BLACK + 800 BLACK 100ML   17,95 EUR
# 33                 CAMISETA TEXTO CONTRASTE   12,95 EUR
# 34          PARKA WATER AND WIND PROTECTION   79,95 EUR
# 35                  TOP DENIM TRF CORSETERO   22,95 EUR
# 36                     PANTALÓN EFECTO PIEL   39,95 EUR
# 37                      CAMISETA ESTRUCTURA   15,95 EUR
# 38            LEVITA CON LANA ZW COLLECTION   99,95 EUR
# 39                         CAMISA ESTAMPADA   25,95 EUR
# 40                    CAMISETA RIB TIRANTES   12,95 EUR
# 41                         BAILARINA BÁSICA   17,95 EUR
# 42            FALDA MINI DOBLE CAPA VOLUMEN   25,95 EUR
# 43     LEGGINGS CICLISTAS CINTURA CONTRASTE   15,95 EUR
# 44        ABRIGO LANA MANTECO ZW COLLECTION  129,00 EUR
# 45                          NECESER GRABADO   19,95 EUR
# 46                 VESTIDO SATINADO TIE DYE   39,95 EUR
# 47             VESTIDO ESTAMPADO GEOMÉTRICO   29,95 EUR
# 48                      BOTÍN TACÓN BRILLOS   69,95 EUR
#
#                                           description  \
# 0   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 1   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 2   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 3   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 4   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 5   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 6   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 7   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 8   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 9   COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 10  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 11  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 12  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 13  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 14  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 15  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 16  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 17  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 18  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 19  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 20  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 21  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 22  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 23  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 24  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 25  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 26  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 27  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 28  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 29  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 30  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 31  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 32  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 33  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 34  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 35  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 36  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 37  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 38  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 39  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 40  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 41  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 42  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 43  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 44  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 45  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 46  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 47  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
# 48  COMPOSICIÓN, CUIDADOS & ORIGENCOMPOSICIÓNTraba...
#
#                                            image_link
# 0   https://static.zara.net/assets/public/dc08/e8c...
# 1   https://static.zara.net/assets/public/05c7/94c...
# 2   https://static.zara.net/photos///2023/I/0/1/p/...
# 3   https://static.zara.net/assets/public/045f/ab6...
# 4   https://static.zara.net/assets/public/8cbc/d41...
# 5   https://static.zara.net/assets/public/0a9f/7c6...
# 6   https://static.zara.net/assets/public/4e23/18f...
# 7   https://static.zara.net/photos///2024/V/1/1/p/...
# 8   https://static.zara.net/assets/public/6e3a/158...
# 9   https://static.zara.net/assets/public/b2df/f05...
# 10  https://static.zara.net/assets/public/db2a/459...
# 11  https://static.zara.net/assets/public/e28e/1df...
# 12  https://static.zara.net/assets/public/28c2/348...
# 13  https://static.zara.net/photos///2023/I/0/3/p/...
# 14  https://static.zara.net/assets/public/c708/089...
# 15  https://static.zara.net/assets/public/45cb/25b...
# 16  https://static.zara.net/assets/public/9373/2af...
# 17  https://static.zara.net/assets/public/d537/533...
# 18  https://static.zara.net/assets/public/7372/05c...
# 19  https://static.zara.net/assets/public/5eee/254...
# 20  https://static.zara.net/assets/public/7587/687...
# 21  https://static.zara.net/assets/public/894d/63a...
# 22  https://static.zara.net/assets/public/1256/ea0...
# 23  https://static.zara.net/assets/public/08aa/ae4...
# 24  https://static.zara.net/assets/public/86f9/4c7...
# 25  https://static.zara.net/assets/public/ff98/a0e...
# 26  https://static.zara.net/assets/public/dc6e/dd5...
# 27  https://static.zara.net/assets/public/9d2c/f81...
# 28  https://static.zara.net/assets/public/18bf/5ef...
# 29  https://static.zara.net/assets/public/0e5b/c19...
# 30  https://static.zara.net/assets/public/9cdf/f99...
# 31  https://static.zara.net/photos///2023/I/0/1/p/...
# 32  https://static.zara.net/assets/public/1ca0/9c8...
# 33  https://static.zara.net/assets/public/65ff/3aa...
# 34  https://static.zara.net/photos///2023/I/0/1/p/...
# 35  https://static.zara.net/assets/public/973c/29f...
# 36  https://static.zara.net/assets/public/f5d6/043...
# 37  https://static.zara.net/assets/public/dbc2/31a...
# 38  https://static.zara.net/assets/public/a2c5/82a...
# 39  https://static.zara.net/assets/public/84d8/8bb...
# 40  https://static.zara.net/assets/public/7240/82c...
# 41  https://static.zara.net/assets/public/cf4c/139...
# 42  https://static.zara.net/assets/public/821f/ffd...
# 43  https://static.zara.net/assets/public/e32e/d35...
# 44  https://static.zara.net/assets/public/2308/235...
# 45  https://static.zara.net/assets/public/23bc/b71...
# 46  https://static.zara.net/assets/public/def1/e72...
# 47  https://static.zara.net/assets/public/3223/b21...
# 48  https://static.zara.net/assets/public/4b7d/cb7...

# %% [markdown]
# Guardando el contenido en un .csv

# %%
current_time = datetime.datetime.now().strftime("%Y_%m_%d-%H_%M_%S")
df.to_csv(f"zara-{current_time}.csv", sep=";")
